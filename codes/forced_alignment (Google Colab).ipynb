# %% [markdown]
# # Run This notebook in google colab!

# %% [markdown]
# ## Instructions:
# ### 1. You should upload your downsampled long audio file(.wav) and preprocessed text file (.txt) to your google drive account
# ### 2. Specify paths to your audio file(.wav), text file(.txt) and output folder. (You should specify all these in the last cell of this notebook)

# %%
# !pip install --pre torchaudio --index-url https://download.pytorch.org/whl/nightly

# %%
# !git clone https://github.com/isi-nlp/uroman.git

# %%
# !apt install sox
# !pip install sox dataclasses

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
# !git clone https://github.com/facebookresearch/fairseq.git

# %%
# !python3 /content/fairseq/examples/mms/data_prep/align_and_segment.py -a "path/to/audio_file.wav" -t "path/to/text_file.txt" -l aze -o "path/to/output/folder" -u "path/to/uroman/uroman"

# %% [markdown]
# #### After executing this notebook, you will have folder full of audio files each contains voice which aligns with each line in your text file. In addtion, in output folder you will have json file containing metadata, but you dont need this json because we will create our own file containing all metadata information
